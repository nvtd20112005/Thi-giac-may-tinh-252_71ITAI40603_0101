# %% [markdown]
# <h1> Geometric Operations and Other Mathematical Tools</h1>

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# <h2>Objectives</h2>

# %% [markdown]
# In the first part of the lab, you will apply geometric transformations to an image. This allows you to perform different operations like reshape translation i.e. to shift, reshape and rotate the image. In the second part of the lab, you will learn how to apply some basic array and matrix operations to the image.

# %% [markdown]
# <ul>
#     <li><a href='#PT'> Geometric Operations  </a>
#         <ul>
#             <li>Scaling  </li>
#             <li>Translation</li>
#             <li>Rotation</li>
#           </ul>
#         <li><a href='#PT'>  Mathematical Operations   </a>
#         <ul>
#             <li>Array Operations  </li>
#             <li>Matix Operations n</li>
#           </ul>
#
#
# </ul>

# %% [markdown]
# ----

# %% [markdown]
# Download the image for the lab:

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-CV0101EN-SkillsNetwork/images%20/images_part_1/lenna.png -O lenna.png  # Tải ảnh từ URL
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-CV0101EN-SkillsNetwork/images%20/images_part_1/baboon.png -O baboon.png  # Tải ảnh từ URL
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-CV0101EN-SkillsNetwork/images%20/images_part_1/barbara.png -O barbara.png    # Tải ảnh từ URL

# %% [markdown]
# We will import the following:

# %%
import matplotlib.pyplot as plt  # Import thư viện matplotlib để vẽ đồ thị
import cv2  # Import thư viện OpenCV để xử lý ảnh
import numpy as np  # Import thư viện numpy để tính toán mảng

# %% [markdown]
# First, let's define a helper function to plot two images side-by-side. You will not need to understand this code this moment, but this function will be used repeatedly in this tutorial to showcase the results.

# %%
def plot_image(image_1, image_2,title_1="Orignal",title_2="New Image"):  # Định nghĩa hàm vẽ 2 ảnh song song
    plt.figure(figsize=(10,10))  # Tạo khung vẽ với kích thước tùy chỉnh
    plt.subplot(1, 2, 1)  # Tạo ô vẽ thứ nhất (bên trái)
    plt.imshow(image_1,cmap="gray")  # Hiển thị ảnh gốc
    plt.title(title_1)  # Đặt tiêu đề ảnh gốc
    plt.subplot(1, 2, 2)  # Tạo ô vẽ thứ hai (bên phải)
    plt.imshow(image_2,cmap="gray")  # Hiển thị ảnh mới
    plt.title(title_2)  # Đặt tiêu đề ảnh mới
    plt.show()  # Hiển thị kết quả

# %% [markdown]
# #  Geometric Transformations

# %% [markdown]
#  Geometric transformations allow you to perform different operations like translation i.e. to shift, reshape and rotate the image.

# %% [markdown]
# ## Scaling

# %% [markdown]
# We can resize an image using the function `resize()` from `cv2` module for this purpose.  You can specify the scaling factor or the size of the image:

# %% [markdown]
# Consider the following image with the corresponding intensity values:

# %%
toy_image = np.zeros((6,6))  # Tạo ảnh mẫu 6x6 toàn số 0
toy_image[1:5,1:5]=255  # Đặt vùng 4x4 trung tâm = 255 (trắng)
toy_image[2:4,2:4]=0  # Đặt vùng 2x2 giữa = 0 (đen)
plt.imshow(toy_image,cmap='gray')
plt.show()  # Hiển thị kết quả
toy_image

# %% [markdown]
# We can rescale along a specific axis:
#
# - `fx`: scale factor along the horizontal axis
# - `fy`: scale factor along the vertical axis

# %% [markdown]
# The parameter interpolation estimates pixel values based on neighboring pixels. <code>INTER_NEAREST</code> uses the nearest pixel and <code>INTER_CUBIC</code> uses several pixels near the pixel value we would like to estimate.

# %%
new_toy = cv2.resize(toy_image,None,fx=2, fy=1, interpolation = cv2.INTER_NEAREST )  # Thay đổi kích thước ảnh (fx: tỷ lệ ngang, fy: tỷ lệ dọc)
plt.imshow(new_toy,cmap='gray')
plt.show()  # Hiển thị kết quả

# %% [markdown]
# Consider the following image:

# %%
image = cv2.imread("lenna.png")  # Đọc ảnh từ file
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))  # Chuyển BGR sang RGB để hiển thị đúng màu
plt.show()  # Hiển thị kết quả

# %% [markdown]
# We can scale the horizontal axis by two and leave the vertical axis as is:

# %%
new_image = cv2.resize(image, None, fx=2, fy=1, interpolation=cv2.INTER_CUBIC)  # Thay đổi kích thước ảnh (fx: tỷ lệ ngang, fy: tỷ lệ dọc)
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))  # Chuyển BGR sang RGB để hiển thị đúng màu
plt.show()  # Hiển thị kết quả
print("old image shape:", image.shape, "new image shape:", new_image.shape)

# %% [markdown]
# In the same manner, we can scale the vertical axis by two:

# %%
new_image = cv2.resize(image, None, fx=1, fy=2, interpolation=cv2.INTER_CUBIC)  # Thay đổi kích thước ảnh (fx: tỷ lệ ngang, fy: tỷ lệ dọc)
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))  # Chuyển BGR sang RGB để hiển thị đúng màu
plt.show()  # Hiển thị kết quả
print("old image shape:", image.shape, "new image shape:", new_image.shape)

# %% [markdown]
# We can scale the horizontal axis and vertical axis by two.

# %%
new_image = cv2.resize(image, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)  # Thay đổi kích thước ảnh (fx: tỷ lệ ngang, fy: tỷ lệ dọc)
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))  # Chuyển BGR sang RGB để hiển thị đúng màu
plt.show()  # Hiển thị kết quả
print("old image shape:", image.shape, "new image shape:", new_image.shape)

# %% [markdown]
# We can also shrink the image by setting the scaling factor to a real number between 0 and 1:

# %%
new_image = cv2.resize(image, None, fx=1, fy=0.5, interpolation=cv2.INTER_CUBIC)  # Thay đổi kích thước ảnh (fx: tỷ lệ ngang, fy: tỷ lệ dọc)
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))  # Chuyển BGR sang RGB để hiển thị đúng màu
plt.show()  # Hiển thị kết quả
print("old image shape:", image.shape, "new image shape:", new_image.shape)

# %% [markdown]
# We can  also specify the number of rows and columns:

# %%
rows = 100  # Số hàng mới
cols = 200  # Số cột mới

# %%
new_image = cv2.resize(image, (100, 200), interpolation=cv2.INTER_CUBIC)  # Thay đổi kích thước ảnh (fx: tỷ lệ ngang, fy: tỷ lệ dọc)
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))  # Chuyển BGR sang RGB để hiển thị đúng màu
plt.show()  # Hiển thị kết quả
print("old image shape:", image.shape, "new image shape:", new_image.shape)

# %% [markdown]
# ## Translation

# %% [markdown]
# Translation is  when you  shift the location of the image. <code>tx</code> is the number of pixels you shift the location in the horizontal direction and <code>ty</code> is the number of pixels you shift in the vertical direction. You can create the transformation matrix $M$ to shift the image.
#
# In this example, we shift the image 100 pixels horizontally:

# %%
tx = 100  # Số pixel dịch theo chiều ngang
ty = 0  # Số pixel dịch theo chiều dọc
M = np.float32([[1, 0, tx], [0, 1, ty]])  # Tạo ma trận biến đổi affine 2x3
M

# %% [markdown]
# The shape of the image is given by:

# %%
rows, cols, _ = image.shape  # Lấy kích thước ảnh (hàng, cột, kênh màu)

# %% [markdown]
# We use the function <code>warpAffine</code> from the <code>cv2</code> module. The first input parater is an image array, the second input parameter is the transformation matrix <code>M</code>, and the final input paramter is the length and width of the output image $(cols,rows)$:

# %%
new_image = cv2.warpAffine(image, M, (cols, rows))  # Áp dụng biến đổi affine (dịch chuyển/xoay ảnh)

# %% [markdown]
# We can plot the image; the portions of the image that do not have any intensities are set to zero:

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))  # Chuyển BGR sang RGB để hiển thị đúng màu
plt.show()  # Hiển thị kết quả

# %% [markdown]
# We can see some of the original image has been cut off. We can fix this by changing the output image size: <code>(cols + tx,rows + ty)</code>:

# %%
new_image = cv2.warpAffine(image, M, (cols + tx, rows + ty))  # Áp dụng biến đổi affine (dịch chuyển/xoay ảnh)
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))  # Chuyển BGR sang RGB để hiển thị đúng màu
plt.show()  # Hiển thị kết quả

# %% [markdown]
# We can shift the image horizontally:

# %%
tx = 0  # Số pixel dịch theo chiều ngang
ty = 50  # Số pixel dịch theo chiều dọc
M = np.float32([[1, 0, tx], [0, 1, ty]])  # Tạo ma trận biến đổi affine 2x3
new_iamge = cv2.warpAffine(image, M, (cols + tx, rows + ty))  # Áp dụng biến đổi affine (dịch chuyển/xoay ảnh)
plt.imshow(cv2.cvtColor(new_iamge, cv2.COLOR_BGR2RGB))  # Chuyển BGR sang RGB để hiển thị đúng màu
plt.show()  # Hiển thị kết quả

# %% [markdown]
# ## Rotation

# %% [markdown]
# We can rotate an image by angle θ which is achieved by the Rotation Matrix <code>getRotationMatrix2D</code>.

# %% [markdown]
# <p><code>center</code>: Center of the rotation in the source image. We will only use the center of the image.</p>
# <p><code>angle</code>: Rotation angle in degrees. Positive values mean counter-clockwise rotation (the coordinate origin is assumed to be the top-left corner).</p>
# <p><code>scale</code>: Isotropic scale factor, in this course the value will be one.</p>

# %% [markdown]
# We can rotate our toy image by 45 degrees:

# %%
theta = 45.0  # Góc xoay (độ)
M = cv2.getRotationMatrix2D(center=(3, 3), angle=theta, scale=1)  # Tạo ma trận xoay với tâm, góc và tỷ lệ
new_toy_image = cv2.warpAffine(toy_image, M, (6, 6))  # Áp dụng biến đổi affine (dịch chuyển/xoay ảnh)

# %%
plot_image(toy_image, new_toy_image, title_1="Orignal", title_2="rotated image")  # Gọi hàm vẽ để so sánh 2 ảnh

# %% [markdown]
# Looking at intensity values, we see that many values have been interpolated:

# %%
new_toy_image

# %% [markdown]
# We can perform the same operation on color images:

# %%
cols, rows, _ = image.shape  # Lấy kích thước ảnh (hàng, cột, kênh màu)

# %%
M = cv2.getRotationMatrix2D(center=(cols // 2 - 1, rows // 2 - 1), angle=theta, scale=1)  # Tạo ma trận xoay với tâm, góc và tỷ lệ
new_image = cv2.warpAffine(image, M, (cols, rows))  # Áp dụng biến đổi affine (dịch chuyển/xoay ảnh)

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))  # Chuyển BGR sang RGB để hiển thị đúng màu
plt.show()  # Hiển thị kết quả

# %% [markdown]
# # Mathematical Operations

# %% [markdown]
# ## Array Operations

# %% [markdown]
# We can perform array operations on an image; Using Python broadcasting, we can add a constant to each pixel's intensity value.

# %%
new_image = image + 20  # Tăng độ sáng bằng cách cộng 20

plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))  # Chuyển BGR sang RGB để hiển thị đúng màu
plt.show()  # Hiển thị kết quả

# %% [markdown]
# We can also multiply every pixel's intensity value by a constant value.

# %%
new_image = 10 * image  # Nhân mỗi pixel với 10 (tăng độ tương phản)
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))  # Chuyển BGR sang RGB để hiển thị đúng màu
plt.show()  # Hiển thị kết quả

# %% [markdown]
# We can add the elements of two arrays of equal shape. In this example, we generate an array of random noises with the same shape and data type as our image.

# %%
Noise = np.random.normal(0, 20, (rows, cols, 3)).astype(np.uint8)  # Tạo nhiễu ngẫu nhiên với phân phối chuẩn
Noise.shape

# %% [markdown]
# We add the generated noise to the image and plot the result. We see the values that have corrupted the image:

# %%
new_image = image + Noise  # Thêm nhiễu vào ảnh

plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))  # Chuyển BGR sang RGB để hiển thị đúng màu
plt.show()  # Hiển thị kết quả

# %% [markdown]
# At the same time, we can multiply the elements of two arrays of equal shape. We can multiply the random image and the Lenna image and plot the result.

# %%
new_image = image*Noise  # Nhân ảnh với nhiễu

plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))  # Chuyển BGR sang RGB để hiển thị đúng màu
plt.show()  # Hiển thị kết quả

# %% [markdown]
# ## Matrix Operations

# %% [markdown]
# Grayscale images are matrices. Consider the following grayscale image:

# %%
im_gray = cv2.imread('barbara.png', cv2.IMREAD_GRAYSCALE)  # Đọc ảnh từ file
im_gray.shape

plt.imshow(im_gray,cmap='gray')
plt.show()  # Hiển thị kết quả

# %% [markdown]
# We can apply algorithms designed for matrices.  We can use  Singular Value Decomposition, decomposing our image matrix into  a product of three matrices.

# %%
U, s, V = np.linalg.svd(im_gray , full_matrices=True)  # Phân tích SVD (Singular Value Decomposition)

# %% [markdown]
# We see <code>s</code> is not rectangular:

# %%
s.shape

# %% [markdown]
# We can convert  <code>s</code> to a diagonal matrix <code>S</code>:

# %%
S = np.zeros((im_gray.shape[0], im_gray.shape[1]))  # Tạo ma trận S dạng đường chéo
S[:image.shape[0], :image.shape[0]] = np.diag(s)  # Chuyển vector s thành ma trận đường chéo

# %% [markdown]
# We can plot the matrix `U` and `V`:

# %%
 plot_image(U,V,title_1="Matrix U ",title_2="matrix  V")  # Gọi hàm vẽ để so sánh 2 ảnh

# %% [markdown]
# We see most of the elements in `S` are zero:

# %%
plt.imshow(S,cmap='gray')
plt.show()  # Hiển thị kết quả

# %% [markdown]
# We can find the matrix product of all the matrices. First, we can perform matrix multiplication on `S` and `U` and assign it  to `B` and plot the results:

# %%
B = S.dot(V)  # Nhân ma trận
plt.imshow(B,cmap='gray')
plt.show()  # Hiển thị kết quả

# %% [markdown]
# We can find the matrix product of `U`, `S`, and `B`. We see it’s the entire image:

# %%
A = U.dot(B)  # Nhân ma trận

# %%
plt.imshow(A,cmap='gray')
plt.show()  # Hiển thị kết quả

# %% [markdown]
# It turns out many elements are redundant, so we can eliminate some rows and columns of `S` and `V` and approximate the image by finding the product.

# %%
for n_component in [1,10,100,200, 500]:  # Vòng lặp với các số thành phần khác nhau
    S_new = S[:, :n_component]  # Cắt ma trận S với n thành phần
    V_new = V[:n_component, :]  # Cắt ma trận V với n thành phần
    A = U.dot(S_new.dot(V_new))  # Nhân ma trận
    plt.imshow(A,cmap='gray')
    plt.title("Number of Components:"+str(n_component))
    plt.show()  # Hiển thị kết quả

# %% [markdown]
# We see we only need 100 to 200 Components to represent the image.

# %% [markdown]
# # References

# %% [markdown]
# [1]  Images were taken from: https://homepages.cae.wisc.edu/~ece533/images/
#
# [2]  <a href='https://pillow.readthedocs.io/en/stable/index.html'>Pillow Docs</a>
#
# [3]  <a href='https://opencv.org/'>Open CV</a>
#
# [4] Gonzalez, Rafael C., and Richard E. Woods. "Digital image processing." (2017).
#
# [5 ] Jian, Wushuai, Xueyan Sun, and Shuqian Luo. "Computer-aided diagnosis of breast microcalcifications based on dual-tree complex wavelet transform." Biomedical engineering online 11.1 (2012): 1-12.

# %% [markdown]
# <!--<h2>Change Log</h2>-->

# %% [markdown]
# <!--
# <table>
#     <tr>
#         <th>Date (YYYY-MM-DD)</th>
#         <th>Version</th>
#         <th>Changed By</th>
#         <th>Change Description</th>
#     </tr>
#     <tr>
#         <td>2020-07-20</td>
#         <td>0.2</td>
#         <td>Azim</td>
#         <td>Modified Multiple Areas</td>
#     </tr>
#     <tr>
#         <td>2020-07-17</td>
#         <td>0.1</td>
#         <td>Azim</td>
#         <td>Created Lab Template</td>
#     </tr>
# </table>
# -->

# %% [markdown]
# <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
